# %%
##### imports

# For the API CAll
import requests

# Basic calculations
import numpy as np

# Plotting
import matplotlib.pyplot as plt

# JSON Handling
import json

# dataframe management
import pandas as pd

# OS
import os
os.chdir('/Users/admin/Desktop/App/app')

#DB
from models import TimeSeriesData, Session

#Datetime
from datetime import datetime

def extract_api_call(sample_key):
    # Split key by "."
    key_list = sample_key.split(".")
    # Extract FlowRef
    flowRef = key_list[0]
    # Extract key 
    key = sample_key[len(key_list[0])+1:]
    # Build call string
    # API Part of URL
    api_part_generic = "https://api.statistiken.bundesbank.de/rest/data/"
    api_part_specific = flowRef+"/"+key
    api_call = api_part_generic + api_part_specific
    return api_call

##### Function that takes in the api-call and performs a request and stores the data in a response_json

def auto_response_saver(api_call):
    #Define the header
    headers = {'accept': 'application/vnd.sdmx.data+json;version=1.0.0',}
    # Define parameters
    params = {'detail': 'full',}
    # Define full-sub
    full_response = '?detail=full'
    # Create full call
    full_call = api_call + full_response
    # Get the actual response
    response = requests.get(full_call, params=params, headers=headers,)
    # As json
    response_list = response.json()
    return(response_list)

##### Take Response and return DF

def extract_response(Response, ColName):
    Response_Numbers = []
    VarKey = list(Response["data"]["dataSets"][0]["series"].keys())[0]

    for key in Response["data"]["dataSets"][0]["series"][VarKey]["observations"]:
        Response_Numbers.append(Response["data"]["dataSets"][0]["series"][VarKey]["observations"][key][0])

    Response_Numbers_PD = pd.DataFrame(Response_Numbers, columns = [ColName])    

    # General Timestamp ["data"]["structure"]["dimensions"]["observation"][0]["values"]
    Response_Timestamp = []

    for element in Response["data"]["structure"]["dimensions"]["observation"][0]["values"]:
        Response_Timestamp.append(element["id"])

    Response_Timestamp_PD = pd.DataFrame(Response_Timestamp, columns = ["time"])

    Response_DF = pd.concat([Response_Timestamp_PD,Response_Numbers_PD],axis=1).set_index("time")
    
    return Response_DF

##### Function, that takes in a KEY and a "Name" that then 
##### builds the api call, fetches the data, extracts the data from the response and returns dataframes separately

def BBK2PD(KEY, ColName):
    Output = extract_response(auto_response_saver(extract_api_call(KEY)), ColName)
    return Output


#####Variable Declaration

Keys_All = {  
"HVPI" :"BBDP1.M.DE.N.HVPI.C.A00000.I15.A",
}

##### Create separate varables from dict

for key, value in Keys_All.items():
    exec(f"{key} = '{value}'")
    
##### Loop through the Dict and save Variables in dataframes
for key, value in Keys_All.items():
     exec(f"{key} = BBK2PD(value, key)")
        
# Create an empty list to store the values and loop through the dictionary and extract the values 
values = []
for key in Keys_All:
    values.append(globals()[key])
#Concat all variables and join the by common index.
DTF = pd.concat(values,axis=1,join="inner")
del values

# %%
print(DTF.head())
print(DTF.columns)
# Out:
#          HVPI
# time
# 1996-01  75.1
# 1996-02  75.6
# 1996-03  75.7
# 1996-04  75.6
# 1996-05  75.7
# Index(['HVPI'], dtype='object')

# %%
##### Write Dataframe into DB

session = Session()

for index, row in DTF.iterrows():
    timestamp = datetime.strptime(index, '%Y-%m').date()
    data = TimeSeriesData(
        name='HVPI',
        timestamp=timestamp,
        value=row['HVPI']
    )
    session.add(data)

session.commit()
session.close()

# %%
session = Session()

# Query data from the database
results = session.query(TimeSeriesData).filter(TimeSeriesData.name == 'HVPI').all()

for result in results:
    print(result.name, result.timestamp, result.value)

session.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt

session = Session()

# Query the database for only the HVPI series
results = session.query(TimeSeriesData).filter(TimeSeriesData.name == "HVPI").all()


# Create a list of dictionaries from the query results
data = [{"name": result.name, "timestamp": result.timestamp, "value": result.value} for result in results]

# Convert the list of dictionaries to a pandas DataFrame
df = pd.DataFrame(data)

# Set the timestamp as the DataFrame index
df.set_index('timestamp', inplace=True)

# Plot the time series data
df.plot(figsize=(12, 6))

# Customize the plot
plt.title("HVPI Time Series")
plt.xlabel("Timestamp")
plt.ylabel("Value")

# Display the plot
plt.show()

session.close()

# %%
print(df.head())
# Out:
#             name  value
# timestamp
# 1996-01-01  HVPI   75.1
# 1996-02-01  HVPI   75.6
# 1996-03-01  HVPI   75.7
# 1996-04-01  HVPI   75.6
# 1996-05-01  HVPI   75.7

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd

# Fit linear regression model to data
X = sm.add_constant(df.index.values.astype(float))
y = df['value'].values.astype(float)
model = sm.OLS(y, X).fit()

# Plot time series data with linear regression line
fig, ax = plt.subplots()
ax.plot(df.index, df['value'])
ax.plot(df.index, model.predict(), color='red')
ax.set_xlabel('Date')
ax.set_ylabel('Value')
ax.legend(['Data', 'Linear Regression'])

# Create table of model statistics
stats = model.summary2().tables[1]
stats.index = pd.Index(['Constant', 'Slope'])
stats.index.name = 'Coefficients'
stats.rename(columns={'Coef.': 'Estimate', 'Std.Err.': 'Std. Error', 't': 't-value', 'P>|t|': 'P-value'}, inplace=True)
stats['Estimate'] = stats['Estimate'].map('{:.2f}'.format)
stats['Std. Error'] = stats['Std. Error'].map('{:.2f}'.format)
stats['t-value'] = stats['t-value'].map('{:.2f}'.format)
stats['P-value'] = stats['P-value'].map('{:.3f}'.format)

# Print table of model statistics
print(stats)

plt.show()
# Out:
#              Estimate Std. Error t-value P-value        [0.025        0.975]
# Coefficients
# Constant         0.00       0.00  234.57   0.000  5.569911e-35  5.664127e-35
# Slope            0.00       0.00  234.57   0.000  7.232088e-17  7.354420e-17

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.626
# Model:                            OLS   Adj. R-squared:                  0.626
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Mon, 01 May 2023   Prob (F-statistic):                nan
# Time:                        16:57:43   Log-Likelihood:                -1107.2
# No. Observations:                 327   AIC:                             2216.
# Df Residuals:                     326   BIC:                             2220.
# Df Model:                           0
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.617e-35   2.39e-37    234.570      0.000    5.57e-35    5.66e-35
# ...

# %%
import statsmodels.api as sm
import html2text

# Fit linear regression model to data
X = sm.add_constant(df.index.values.astype(float))
y = df['value'].values.astype(float)
model = sm.OLS(y, X).fit()

# Get model summary as an HTML table
summary_html = model.summary().tables[1].as_html()

# Convert HTML to markdown
converter = html2text.HTML2Text()
converter.body_width = 0
summary_markdown = converter.handle(summary_html)

# Print model summary in markdown format
print(summary_markdown)
# Out:
# | coef | std err | t | P>|t| | [0.025 | 0.975]
# ---|---|---|---|---|---|---
# const |  5.617e-35 |  2.39e-37 |  234.570 |  0.000 |  5.57e-35 |  5.66e-35
# x1 |  7.293e-17 |  3.11e-19 |  234.570 |  0.000 |  7.23e-17 |  7.35e-17

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

def plot_regression_last_n_days(df, n):
    # Fit linear regression model to data from last n days
    X = sm.add_constant(df.index[-n:].values.astype(float))
    y = df['value'][-n:].values.astype(float)
    model = sm.OLS(y, X).fit()

    # Generate predicted values for last n days
    X_pred = sm.add_constant(df.index[-n:].values.astype(float))
    y_pred = model.predict(X_pred)

    # Plot time series data with regression line for last n days
    fig, ax = plt.subplots()
    ax.plot(df.index, df['value'])
    ax.plot(df.index[-n:], y_pred, color='red', linestyle='dotted')
    ax.set_xlabel('Date')
    ax.set_ylabel('Value')
    ax.legend(['Data', 'Regression Line'])
    plt.show()


plot_regression_last_n_days(df, 10)

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

def plot_rolling_loglik(df, n):
    # Compute rolling log-likelihood values for linear regression over last n days
    X = sm.add_constant(df.index.values.astype(float))
    y = df['value'].values.astype(float)
    logliks = pd.Series(index=df.index, dtype=float)
    for i in range(n, len(df)):
        X_subset = X[i-n:i+1]
        y_subset = y[i-n:i+1]
        model = sm.OLS(y_subset, X_subset).fit()
        logliks.iloc[i] = model.llf

    # Plot rolling log-likelihood values
    fig, ax = plt.subplots()
    ax.plot(logliks.index, logliks)
    ax.set_xlabel('Date')
    ax.set_ylabel('Log-Likelihood')
    plt.show()

plot_rolling_loglik(df, 12)

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

def plot_rolling_loglik_and_aic(df, n):
    # Compute rolling log-likelihood and AIC values for linear regression over last n days
    X = sm.add_constant(df.index.values.astype(float))
    y = df['value'].values.astype(float)
    logliks = pd.Series(index=df.index, dtype=float)
    aics = pd.Series(index=df.index, dtype=float)
    for i in range(n, len(df)):
        X_subset = X[i-n:i+1]
        y_subset = y[i-n:i+1]
        model = sm.OLS(y_subset, X_subset).fit()
        logliks.iloc[i] = model.llf
        aics.iloc[i] = model.aic

    # Plot scatter plot of rolling log-likelihood and AIC values
    fig, ax = plt.subplots()
    ax.scatter(logliks, aics)
    ax.set_xlabel('Log-Likelihood')
    ax.set_ylabel('AIC')
    plt.show()

plot_rolling_loglik_and_aic(df,12)

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

def plot_rolling_regression_metrics(df, n):
    # Compute rolling regression metrics for last n days
    X = sm.add_constant(df.index.values.astype(float))
    y = df['value'].values.astype(float)
    rsquareds = pd.Series(index=df.index, dtype=float)
    aics = pd.Series(index=df.index, dtype=float)
    logliks = pd.Series(index=df.index, dtype=float)
    coefficients = pd.Series(index=df.index, dtype=float)
    for i in range(n, len(df)):
        X_subset = X[i-n:i+1]
        y_subset = y[i-n:i+1]
        model = sm.OLS(y_subset, X_subset).fit()
        rsquareds.iloc[i] = model.rsquared
        aics.iloc[i] = model.aic
        logliks.iloc[i] = model.llf
        coefficients.iloc[i] = model.params[1]

    # Plot rolling metrics in separate plots
    fig1, ax1 = plt.subplots()
    ax1.plot(logliks.index, logliks)
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Log-Likelihood')

    fig2, ax2 = plt.subplots()
    ax2.plot(aics.index, aics)
    ax2.set_xlabel('Date')
    ax2.set_ylabel('AIC')

    fig3, ax3 = plt.subplots()
    ax3.plot(rsquareds.index, rsquareds)
    ax3.set_xlabel('Date')
    ax3.set_ylabel('R-Squared')

    fig4, ax4 = plt.subplots()
    ax4.plot(coefficients.index, coefficients)
    ax4.set_xlabel('Date')
    ax4.set_ylabel('Coefficient')

    plt.show()

plot_rolling_regression_metrics(df, 24)

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

def plot_regression_and_r2(df, n):
    # Select the last n months of data
    last_n_months = df.iloc[-n:]

    # Compute linear regression and R-squared
    X = sm.add_constant(np.arange(n))
    y = last_n_months['value']
    results = sm.OLS(y, X).fit()
    r2 = results.rsquared

    # Plot the time series and regression line
    fig, ax = plt.subplots()
    ax.plot(df.index[-n:], df['value'].tail(n), label='Inflation')
    ax.plot(last_n_months.index, results.fittedvalues, label='Regression Line', linestyle='--', color='red')
    ax.set_xlabel('Date')
    ax.set_ylabel('Inflation')
    ax.set_title(f'Inflation with {n}-Month Regression Line')
    ax.text(0.95, 0.05, f'R-Squared: {r2:.2f}', transform=ax.transAxes, ha='right', va='bottom')
    ax.legend()

    plt.show()

plot_regression_and_r2(df,60)
